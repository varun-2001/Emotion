# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
#READING IMAGE
img=cv2.imread('neutral.jpg')

# %%
#DISPLAY IMAGE IN STANDARD RGB COLORSCALE
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
#ANALYSING THE IMAGE USING DEEPFACE
predictions = DeepFace.analyze(img)
print(predictions['emotion'])
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  3.04it/s]
# {'angry': 2.2965876385569572, 'disgust': 1.9345206325738218e-06, 'fear': 0.22400585003197193, 'happy': 0.9216189384460449, 'sad': 3.184039890766144, 'surprise': 0.04260471905581653, 'neutral': 93.33114624023438}

# %%
#USES HAAR CASCADE CLASSIFIER TO DETECT FACES
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
#CONVERTS IMAGE TO GRAYSCALE FOR DETECTION OF BRIGHT AND DARK AREAS
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray, 1.1, 4)

#DRAWS A RECTANGLE AROUND THE FACES DETECTED
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
cv2.putText(img, predictions['dominant_emotion'],
            (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
